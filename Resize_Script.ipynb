# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pillow
import os,sys
import PIL
from PIL import Image

# %%
photo_dir = './fisheye_day/images/validation/'
files = os.listdir(photo_dir)
print(len(files))
# Out:
# 2033

# %%
size = (1024,1024)
# source_files=['01_fisheye_day_000014.jpg']
source_files = os.listdir(photo_dir)
dest_path = photo_dir #Add dest path
for file_ in source_files:
  file_ = photo_dir +"/" + file_
  img = Image.open(file_)
  width, height = img.size
  if(width == size[0] and height == size[0]):
    print("here")
    continue
  img.thumbnail(size,Image.ANTIALIAS)
  img.save(file_)
# Out:
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# ...

# %%
import os
sf=os.listdir('./fisheye_day/images/train/')
lf=os.listdir('./fisheye_day/labels/train/')
#for f in sf:
#    lbl=f.split(".jpg")[0]+".txt"
#    if lbl not in lf:
#        print(f)
len(sf)
# Out:
# 89259

# %%
len(lf)
# Out:
# 89259
